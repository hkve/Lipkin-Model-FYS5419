# %% [markdown]
# # Vårt superprosjekt

# %% [markdown]
# ## a
#
# We initalize and test the functionality of Qiskit as follows

# %%
import numpy as np
import matplotlib.pyplot as plt
from functools import partial
from scipy.optimize import minimize
from qiskit import QuantumCircuit,Aer,assemble, ClassicalRegister,QuantumRegister, execute, transpile
from qiskit.visualization import array_to_latex, plot_histogram,plot_bloch_vector, plot_state_city, plot_bloch_multivector,plot_state_qsphere
from qiskit.quantum_info import DensityMatrix, Statevector
from qiskit.algorithms.minimum_eigensolvers import VQE
from qiskit.quantum_info.operators import Operator, Pauli
from qiskit.opflow import X, Z, I, AerPauliExpectation
from qiskit.primitives import Estimator

#optimizer = partial(minimize, method="L-BFGS-B")
state_sim = Aer.get_backend('statevector_simulator')
simulator = Aer.get_backend('aer_simulator')


I = np.eye(2)
X = np.array([[0,1],[1,0]])
Y = np.array([[0,-1j],[1j,0]])
Z = np.array([[1,0],[0,-1]])
pauli_x = np.matrix([[0,1],[1,0]])
pauli_z = np.matrix([[1,0],[0,-1]])

# %%
from qiskit.circuit import QuantumCircuit,\
                           Parameter
var_par1 = Parameter('theta')
var_par2 = Parameter('phi')

qc_ = QuantumCircuit(2)

qc_.ry(var_par1,0)
qc_.cry(var_par2,0,1)
qc_.draw()
qc_.draw(output = 'mpl', style =  'iqx', filename = 'ansatz.pdf')

# %%
a = np.sqrt(2)
plot_bloch_vector([1/a,0,1/a], title="Bloch-Sphere of a xz-state")

# %%
qc_par = qc_.bind_parameters({var_par1: np.pi/3, var_par2: np.pi/4})

qc_par.draw('mpl')

# %%
state = Statevector(qc_par)
plot_state_city(state)

# %%
out1 = execute(qc_par,state_sim).result().get_statevector()
plot_bloch_multivector(out1)

# %%
qr = QuantumRegister(1, 'Qreg')
cr = ClassicalRegister(1, 'Creg')

qc = QuantumCircuit()
qc.add_register(qr)
qc.add_register(cr)

qc.x(0)
qc.y(0)
qc.z(0)
qc.h(0)
qc.p(np.pi/2, 0)


qc.draw('mpl')

# %% [markdown]
# Initialize a Bell state by applying Haddamard to G0 and CNOT on G1, using G0 as control gate.

# %%
qc_2 = QuantumCircuit()

qr_2 = QuantumRegister(3, 'qreg')
qc_2.add_register(qr_2)

cr_2 = ClassicalRegister(3, 'creg')
qc_2.add_register(cr_2)
qc_2.h(0)
qc_2.cx(0,1)
qc_2.cx(1,2)

state = Statevector(qc_2)
plot_state_city(state)

# %%
out1 = execute(qc_2,state_sim).result().get_statevector()
plot_bloch_multivector(out1)

# %%
plot_state_qsphere(state)

# %%
qc_2.measure(0,0)
qc_2.measure(1,1)
qc_2.measure(2,2)

qc_2.draw('mpl')

# %%
job = simulator.run(qc_2, shots=1000)
hist = job.result().get_counts()
plot_histogram(hist)

# %% [markdown]
# This is statistically in accordance with the expected GHZ states.

# %% [markdown]
# ## b
#
#
# Here we initialize the Hamiltonian matrices and solve it using eigsolvers.

# %%
H0 = np.eye(2)
E1 = 0; E2 = 4
H0[0,0] = E1; H0[1,1] = E2


H1 = np.eye(2)
v11 = 3; v22 = -v11; v12 = 0.2; v21 = v12
H1[0,0] = v11; H1[0,1] = v12; H1[1,0] = v21; H1[1,1] = v22 

lmd_ = 2/3#Range [0,1]
pauli_x = np.matrix([[0,1],[1,0]])
pauli_z = np.matrix([[1,0],[0,-1]])
c = (v11 + v22)/2
omega_z = (v11-v22)/2
omega_x = v12

H_ = H0 + lmd_*H1

print(H_)
print()
eig_val, eig_vec = np.linalg.eig(H_)
print(eig_val,'\n\n', eig_vec)


n = 1000
lambdas = np.linspace(0,1,n)
Es = np.zeros((n,2))
C1s, C2s  = np.zeros_like(Es), np.zeros_like(Es)
for i, lmd_ in enumerate(lambdas):
    H_ = H0 + lmd_*H1
    eig_val, eig_vec = np.linalg.eigh(H_)
    # print(H_)
    Es[i,:] = eig_val
    C1s[i,:] = eig_vec[:,0]
    C2s[i,:] = eig_vec[:,1] 

fig, ax = plt.subplots()
ax.plot(lambdas, Es[:,0], label=r"$E_0$")
ax.plot(lambdas, Es[:,1], label=r"$E_1$")
ax.set(xlabel=r"$\lambda$", ylabel="E [magic]")
ax.legend() # Kan legge til fancy-pancy color bar for a vise "change of character" opplegget?
# Out:
# [[2.         0.13333333]
#  [0.13333333 2.        ]]
#
# [2.13333333 1.86666667]
#
#  [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ## c

# %%
qc_3 = QuantumCircuit()

qr_3 = QuantumRegister(2, 'qreg')
qc_3.add_register(qr_3)

cr_3 = ClassicalRegister(2, 'creg')
qc_3.add_register(cr_3)

eta = (E1 + E2)/2
Omega = (E1-E2)/2
H0 = eta*np.eye(2) + Omega*pauli_z
are = Operator(Pauli('X'))

H1 = c * np.eye(2) + omega_z * pauli_z + omega_x * pauli_x

X_op = Operator(Pauli('X'))
Z_op = Operator(Pauli('Z'))
idty = Operator(np.eye(2))

qc_3.save_statevector()
qc_3.measure(qr_3[0], cr_3[0])
qc_3.measure(qr_3[1], cr_3[1])
qc_3.draw('mpl')

# %% [markdown]
# En måte:

# %%
I = np.eye(2)
X = np.array([[0,1],[1,0]])
Y = np.array([[0,-1j],[1j,0]])
Z = np.array([[1,0],[0,-1]])

# %%
c = (v11 + v22)/2
omega_z = (v11-v22)/2
omega_x = v12
eta = (E1+E2)/2
omega_ = (E1-E2)/2

HH = eta*np.kron(I,I) + omega_ * np.kron(Z,I) + c * np.kron(I,I) + omega_z * np.kron(I,Z) + omega_x * np.kron(I,X) 
val, vec = np.linalg.eig(HH)
print(val)

h1_val = c + eta
h2_val = omega_
h3_val = omega_z
h4_val = omega_x

h1 = [h1_val, [0,1] , ['I']]
h2 = [h2_val, [0] , ['Z']]
h3 = [h3_val, [1] , ['Z']]
h4 = [h4_val, [1] , ['X']]

H = [h1,h2,h3,h4]
H
# Out:
# [ 3.00665928 -3.00665928  7.00665928  0.99334072]
# [[2.0, [0, 1], ['I']],
#  [-2.0, [0], ['Z']],
#  [3.0, [1], ['Z']],
#  [0.2, [1], ['X']]]

# %%
def ansatz(theta,n_qubits):
    qreg = QuantumRegister(n_qubits)
    circuit = QuantumCircuit(qreg)
    param_list =[]
    for j in range(len(theta)):
        par = Parameter('theta %s' %j)
        param_list.append(par)
    for i in range(n_qubits):
        circuit.ry(param_list[i],qreg[i])
    for i in range(n_qubits-1):
        circuit.cx(qreg[i],qreg[i+1])
    dictus ={}
    for j in range(len(theta)):
        dictus[param_list[j]] = theta[j]
    circuit = circuit.bind_parameters(dictus)
    return(circuit)

cc = ansatz([0,1], 2)
cc.draw('mpl')

# %%
n_qbits = 2
theta = np.random.randn(2)

qc = QuantumCircuit()
qreg = QuantumRegister(2)
creg = ClassicalRegister(2)

qc.add_register(qreg)
qc.add_register(creg)
qc.h(qreg[:])

print('Before ansatz')
qc.draw('mpl')
# Out:
# Before ansatz

# %%
qc = qc.compose(ansatz(theta,n_qbits))
print('After ansatz')
qc.draw('mpl')
# Out:
# After ansatz

# %%
def basis_change(h_i,n_qubits):
    qreg = QuantumRegister(n_qubits)
    circuit = QuantumCircuit(qreg)
    for qubit,operator in zip(h_i[1],h_i[2]):
        if operator == 'X':
            circuit.h(qreg[qubit]) 
    return(circuit)

# %%
n_qubits = 2
theta = np.random.randn(n_qubits)

qreg = QuantumRegister(n_qubits)
qc = QuantumCircuit(qreg)
qc = qc.compose(ansatz(theta,n_qubits))
qc = qc.compose(basis_change(H[0],n_qubits))
print('After basis transformation:')
qc.draw('mpl')
# Out:
# After basis transformation:

# %%
def get_energy(theta):
    n_qubits = 2
    qreg = QuantumRegister(n_qubits)
    qc = QuantumCircuit(qreg)
    qc = qc.compose(ansatz(theta,n_qubits))
    qc_list = []
    for idx,h_i in enumerate(H):
        basis_change_circuit = basis_change(h_i,n_qubits)
        new_qc = qc.compose(basis_change_circuit)
        creg = ClassicalRegister(len(h_i[1]))
        new_qc.add_register(creg)
        new_qc.measure(qreg[h_i[1]],creg)
        qc_list.append(new_qc)
        
    shots = 1000
    job = simulator.run(qc_list,shots=shots)
    E = np.zeros(len(qc_list))
    for i in range(len(E)):
        result = job.result()
        counts = result.get_counts(i)
        for key,value in counts.items():
            e = 1
            for bit in key:
                if bit == '0':
                    e *= 1
                if bit == '1':
                    e *= -1
            E[i] += e*value
        E[i] *= H[i][0]
    E /= shots
    return(np.sum(E))

theta = np.random.randn(2)

get_energy(theta)
# Out:
# 1.1332

# %%
def compute_gradient(theta, epsilon=1e-2):
    gradient = np.zeros_like(theta)
    for i in range(len(theta)):
        theta_plus = np.copy(theta)
        theta_minus = np.copy(theta)
        theta_plus[i] += epsilon  #np.pi/10   
        theta_minus[i] -= epsilon #np.pi/10  
        energy_plus = get_energy(theta_plus)
        energy_minus = get_energy(theta_minus)
        gradient[i] = ((energy_plus - energy_minus) / (2 * epsilon))
    return gradient

def gradient_descent(theta, learning_rate, num_iterations):
    min_theta = theta
    min_eval  = get_energy(theta)
    for iteration in range(num_iterations):
        energy = get_energy(theta)
        gradient = compute_gradient(theta)
        theta -= (learning_rate * gradient)
        """
        if iteration%10 == True:
            print("Iteration:", iteration, "Energy:", energy)
        """
        if energy < min_eval:
            min_theta = theta 
            min_eval  = energy
    return min_theta, min_eval

theta = np.array([0.1,0.1])
learning_rate = 0.08
num_iterations = 1000

arg_best, arg_val  = gradient_descent(theta, learning_rate, num_iterations)
print("The lowest energy is:",arg_val,"with theta values of", arg_best)
# Out:
# The lowest energy is: -7.0264 with theta values of [-6.484  -2.8152]

# %% [markdown]
# ## d

# %%
lmd_ = 0.4
s_00 = np.array([1,0,0,0])
s_10 = np.array([0,1,0,0])
s_01 = np.array([0,0,1,0])
s_11 = np.array([0,0,0,1])
s_0 = np.array([1,0])
s_1 = np.array([0,1])


eps_list = [0,2.5,6.5,7]
H0 = np.eye(4)
H0[0,0] = eps_list[0];H0[1,1] = eps_list[1];H0[2,2] = eps_list[2];H0[3,3] = eps_list[3]

pauli_x = np.matrix([[0,1],[1,0]])
pauli_z = np.matrix([[1,0],[0,-1]])
H_x = 2.0
H_z = 3.0
H_I = H_x * np.kron(pauli_x, pauli_x) + H_z * np.kron(pauli_z, pauli_z)

H_tot = H0 + lmd_*H_I
eig_vals, eig_vecs = np.linalg.eig(H_tot)
#print(eig_vecs)

eig_vecs = np.square(eig_vecs)
rho_d = eig_vecs.T @ eig_vecs

print(rho_d)
#Computing partial density matrix
#rho_a = (eig_vecs[0,0]**2 + eig_vecs[0,1]**2) * np.outer(s_0,s_0) + (eig_vecs[0,2]**2 + eig_vecs[0,3]**2) * np.outer(s_1,s_1)
#rho_b = (eig_vecs[0,0]**2 + eig_vecs[0,2]**2) * np.outer(s_0,s_0) + (eig_vecs[0,1]**2 + eig_vecs[0,3]**2) * np.outer(s_1,s_1)
#tol = 1e-3

#print(rho_a)
#print(rho_b)
#print(np.log(rho_a+tol))
#print()
#print(np.trace(rho_b))
#Compute entropy
#S_a = - np.trace(rho_a)*np.log(np.trace(rho_a+tol))
#S_b = - np.trace(rho_b)*np.log(np.trace(rho_b)+tol)
#var = np.trace(np.log(rho_a))
#print(rar)
#print(S_a, S_b)
# Out:
# [[0.97517455 0.02482545 0.         0.        ]
#  [0.02482545 0.97517455 0.         0.        ]
#  [0.         0.         0.93103448 0.06896552]
#  [0.         0.         0.06896552 0.93103448]]

# %%
lmd_ = 2
H_tot = H0 + lmd_*H_I
eig_vals0, eig_vecs0 = np.linalg.eig(H0)
eig_vals_i, eig_vecs_i = np.linalg.eig(lmd_*H_I)

eig_vals, eig_vecs = np.linalg.eig(H_tot)
permute = eig_vals.argsort()
eig_vals = eig_vals[permute]
eig_vecs = eig_vecs[:,permute]
DM = np.outer(eig_vecs[:,0], eig_vecs[:,0])

d = np.matrix([[1,0],[0,1]])

v1 = [1,0]
proj1 = np.kron(v1,d)
x1 = proj1@DM@proj1.T


v2 = [0,1]
proj2 = np.kron(v2,d)
x2 = proj2@DM@proj2.T

# %%
plot_state_qsphere(DM)

# %%
plot_bloch_multivector(DM, title=f'Bloch Spheres for density matrix given $\lambda$= {lmd_}')

# %%
plot_state_city(x1, color=['midnightblue', 'midnightblue'], title=f'Reduced density matrix  for $ \lambda$: {lmd_}')

# %%
plot_state_city(x2, color=['midnightblue', 'midnightblue'], title=f'Reduced density Matrix  for $\lambda$: {lmd_}')

# %%
def entropy(lmd_):
    H_tot = H0 + lmd_*H_I
    eig_vals, eig_vecs = np.linalg.eig(H_tot)
    #print(eig_vecs)
    #print()
    #Computing partial density matrix
    rho_a = (eig_vecs[0,0]**2 + eig_vecs[0,1]**2) * np.outer(s_0,s_0) + (eig_vecs[0,2]**2 + eig_vecs[0,3]**2) * np.outer(s_1,s_1)
    rho_b = (eig_vecs[0,0]**2 + eig_vecs[0,2]**2) * np.outer(s_0,s_0) + (eig_vecs[0,1]**2 + eig_vecs[0,3]**2) * np.outer(s_1,s_1)
    #Compute entropy
    S_a = - np.trace(rho_a)*np.log2(np.trace(rho_a))
    S_b = - np.trace(rho_b)*np.log2(np.trace(rho_b))
    return S_a, S_b

lambda_list = np.linspace(0, 2, 100)
rho_a_list = []
rho_b_list = []
for i in range(len(lambda_list)):
    S_a_var, S_b_var = entropy(lambda_list[i])
    rho_a_list.append(S_a_var)
    rho_b_list.append(S_b_var)
    
plt.figure()
#plt.plot(lambda_list,rho_a_list)
plt.title('Entropy as a function of connection strength')
plt.xlabel('v')
plt.ylabel('$S_{a}$')
plt.savefig('entropy.pdf')
plt.plot(lambda_list,rho_b_list)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 18
#      16 rho_b_list = []
#      17 for i in range(len(lambda_list)):
# ---> 18     S_a_var, S_b_var = entropy(lambda_list[i])
#      19     rho_a_list.append(S_a_var)
#      20     rho_b_list.append(S_b_var)
#
# Cell In[17], line 2, in entropy(lmd_)
#       1 def entropy(lmd_):
# ----> 2     H_tot = H0 + lmd_*H_I
#       3     eig_vals, eig_vecs = np.linalg.eig(H_tot)
#       4     #print(eig_vecs)
#       5     #print()
#       6     #Computing partial density matrix
#
# NameError: name 'H0' is not defined

# %% [markdown]
# ## e

# %%
n = 1000
lambdas = np.linspace(0,1,n)
Es = np.zeros((n,4))
C1s, C2s  = np.zeros_like(Es), np.zeros_like(Es)

for i, lmd_ in enumerate(lambdas):
    H_ = H0 + lmd_*H1
    eig_val, eig_vec = np.linalg.eigh(H_)
    Es[i,:] = eig_val

fig, ax = plt.subplots()
ax.plot(lambdas, Es[:,0], label=r"$E_0$")
ax.plot(lambdas, Es[:,1], label=r"$E_1$")
ax.set(xlabel=r"$\lambda$", ylabel="E [magic]")
ax.legend()

# %% [markdown]
# The entropy is as expected, similar, as there are no difference in the configuration of the two states. As such, there should be an equal amount of entanglement entropy. The energies follow the same asymptotic convergence, which indeed confirms their entanglement.

# %%
I = np.eye(2)
X = np.array([[0,1],[1,0]])
Y = np.array([[0,-1j],[1j,0]])
Z = np.array([[1,0],[0,-1]])
hx = 2; hz = 3; eps_list = [0,2.5,6.5,7]

H_0 = np.matrix([[eps_list[0],0,0,0],[0,eps_list[1],0,0],[0,0,eps_list[2],0],[0,0,0,eps_list[3]]])
H_I = hx * np.kron(X,X) + hz* np.kron(Z,Z) 
H = H_0 + H_I
eigvals,eigvecs = np.linalg.eigh(H)
print(eigvals)
print(eigvecs)

c_1 = 1
c_2 = 1
c_3 = 1

h_1 = [c_1,[0],['z,z']]
h_2 = [c_2,[1],['x,x']]
H = [h_1,h_2]
# Out:
# [-1.32842712  2.46887113  4.32842712 10.53112887]
# [[-0.         -0.96649965  0.         -0.25666794]
#  [ 0.92387953  0.         -0.38268343  0.        ]
#  [-0.38268343  0.         -0.92387953  0.        ]
#  [ 0.          0.25666794  0.         -0.96649965]]

# %%
n_qubits= 2
qreg = QuantumRegister(n_qubits)
circuit = QuantumCircuit(qreg)
circuit.h(qreg[:2])
print('Before ansatz')
print(circuit.draw())
theta = np.random.randn(2)
n_qubits = 2
circuit = circuit.compose(ansatz(theta,n_qubits))
print('After ansatz')
print(circuit.draw())
# Out:
# Before ansatz
#        ┌───┐
# q22_0: ┤ H ├
#        ├───┤
# q22_1: ┤ H ├
#        └───┘
# After ansatz
#        ┌───┐  ┌────────────────────┐
# q22_0: ┤ H ├──┤ Ry(1.240977277925) ├───■──────────────────────────────■──
#        ├───┤┌─┴────────────────────┴┐┌─┴─┐┌────────────────────────┐┌─┴─┐
# q22_1: ┤ H ├┤ Ry(0.172650179574386) ├┤ X ├┤ Ry(-0.172650179574386) ├┤ X ├
#        └───┘└───────────────────────┘└───┘└────────────────────────┘└───┘

# %%
def basis_change(h_i,n_qubits):
    qreg = QuantumRegister(n_qubits)
    circuit = QuantumCircuit(qreg)
    
    for qubit,operator in zip(h_i[1],h_i[2]):
        if operator == 'x':
            circuit.h(qreg[qubit])
    return(circuit)
n_qubits = 2
qreg = QuantumRegister(n_qubits)
circuit = QuantumCircuit(qreg)
theta = np.random.randn(n_qubits)
circuit = circuit.compose(ansatz(theta,n_qubits))
print('Ansatz circuit')
print(circuit.draw())
circuit = circuit.compose(basis_change(H[1],n_qubits))
print('After basis transformation:')
print(circuit.draw())
# Out:
# Ansatz circuit
#          ┌──────────────────────┐
# q26_0: ──┤ Ry(1.28400587416963) ├───■──────────────────────────────■──
#        ┌─┴──────────────────────┴┐┌─┴─┐┌────────────────────────┐┌─┴─┐
# q26_1: ┤ Ry(-0.0568234524659587) ├┤ X ├┤ Ry(0.0568234524659587) ├┤ X ├
#        └─────────────────────────┘└───┘└────────────────────────┘└───┘
# After basis transformation:
#          ┌──────────────────────┐
# q26_0: ──┤ Ry(1.28400587416963) ├───■──────────────────────────────■──
#        ┌─┴──────────────────────┴┐┌─┴─┐┌────────────────────────┐┌─┴─┐
# q26_1: ┤ Ry(-0.0568234524659587) ├┤ X ├┤ Ry(0.0568234524659587) ├┤ X ├
#        └─────────────────────────┘└───┘└────────────────────────┘└───┘

# %%
def get_energy(theta):
    n_qubits = 2
    qreg = QuantumRegister(n_qubits)
    circuit = QuantumCircuit(qreg)
    circuit = circuit.compose(ansatz(theta,n_qubits))
    circuit_list = []
    for idx,h_i in enumerate(H):
        basis_change_circuit = basis_change(h_i,n_qubits)
        new_circuit = circuit.compose(basis_change_circuit)
        creg = ClassicalRegister(len(h_i[1]))
        new_circuit.add_register(creg)
        new_circuit.measure(qreg[h_i[1]],creg)
        circuit_list.append(new_circuit)
    shots = 10000
    job = simulator.run(circuit_list,shots=shots)
    E = np.zeros(len(circuit_list))
    for i in range(len(circuit_list)):
        result = job.result()
        counts = result.get_counts(i)
        for key,value in counts.items():
            e = 1
            for bit in key:
                if bit == '0':
                    e *= 1
                if bit == '1':
                    e *= -1
            E[i] += e*value
        E[i] *= H[i][0]
    E /= shots
    return(np.sum(E)), circuit_list

theta = np.random.randn(2)
e, circ = get_energy(theta)
circ.draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 34
#      32 theta = np.random.randn(2)
#      33 e, circ = get_energy(theta)
# ---> 34 circ.draw()
#
# AttributeError: 'list' object has no attribute 'draw'

# %%
def compute_gradient(theta, epsilon=1e-2):
    gradient = np.zeros_like(theta)
    for i in range(len(theta)):
        theta_plus = np.copy(theta)
        theta_minus = np.copy(theta)
        theta_plus[i] += epsilon  #np.pi/10   
        theta_minus[i] -= epsilon #np.pi/10  
        energy_plus = get_energy(theta_plus)
        energy_minus = get_energy(theta_minus)
        gradient[i] = ((energy_plus - energy_minus) / (2 * epsilon))
    return gradient

def gradient_descent(theta, learning_rate, num_iterations):
    min_theta = theta
    min_eval  = get_energy(theta)
    for iteration in range(num_iterations):
        energy = get_energy(theta)
        gradient = compute_gradient(theta)
        theta -= (learning_rate * gradient)
        """
        if iteration%10 == True:
            print("Iteration:", iteration, "Energy:", energy)
        """
        if energy < min_eval:
            min_theta = theta 
            min_eval  = energy
    return min_theta, min_eval

theta = np.array([0.1,0.1])
learning_rate = 0.08
num_iterations = 1000

arg_best, arg_val  = gradient_descent(theta, learning_rate, num_iterations)
print("The lowest energy is:",arg_val,"with theta values of", arg_best)
# Out:
# 0 2.8587599999999997
# 1 2.5185999999999997
# 2 1.74168
# 3 0.23412000000000022
# 4 -2.06448
# 5 -4.63068
# 6 -6.2926400000000005
# 7 -6.95284
# 8 -7.1316
# 9 -7.18796
# 10 -7.19696
# 11 -7.19956
# 12 -7.2
# 13 -7.2
# 14 -7.19956
# 15 -7.1994
# 16 -7.1994
# 17 -7.2
# 18 -7.2
# 19 -7.2
# 20 -7.2
# 21 -7.2
# 22 -7.2
# 23 -7.2
# 24 -7.2
# 25 -7.2
# 26 -7.2
# 27 -7.1994
# 28 -7.2
# 29 -7.2
# 30 -7.2
# 31 -7.2
# 32 -7.2
# 33 -7.2
# 34 -7.2
# 35 -7.2
# 36 -7.2
# 37 -7.19996
# 38 -7.2
# 39 -7.2
# 40 -7.2
# 41 -7.2
# 42 -7.2
# 43 -7.2
# 44 -7.2
# 45 -7.2
# 46 -7.2
# 47 -7.2
# 48 -7.19996
# 49 -7.2
# 50 -7.2
# 51 -7.19996
# 52 -7.2
# 53 -7.2
# 54 -7.2
# 55 -7.2
# 56 -7.2
# 57 -7.2
# 58 -7.2
# 59 -7.2
# 60 -7.2
# 61 -7.2
# 62 -7.2
# 63 -7.1994
# 64 -7.2
# 65 -7.2
# 66 -7.2
# 67 -7.2
# 68 -7.2
# 69 -7.2
# 70 -7.2
# 71 -7.2
# 72 -7.2
# 73 -7.2
# 74 -7.2
# 75 -7.2
# 76 -7.2
# 77 -7.2
# 78 -7.2
# 79 -7.2
# 80 -7.2
# 81 -7.2
# 82 -7.2
# 83 -7.2
# 84 -7.2
# 85 -7.2
# 86 -7.2
# 87 -7.2
# 88 -7.2
# 89 -7.2
# 90 -7.1994
# 91 -7.2
# 92 -7.2
# 93 -7.2
# 94 -7.1994
# 95 -7.2
# 96 -7.19996
# 97 -7.2
# 98 -7.2
# 99 -7.2
# 100 -7.2
# 101 -7.2
# 102 -7.2
# 103 -7.2
# 104 -7.2
# 105 -7.2
# 106 -7.2
# 107 -7.2
# 108 -7.2
# 109 -7.2
# 110 -7.2
# 111 -7.2
# 112 -7.2
# 113 -7.2
# 114 -7.1996
# 115 -7.2
# 116 -7.2
# 117 -7.2
# 118 -7.2
# 119 -7.2
# 120 -7.2
# 121 -7.2
# 122 -7.2
# 123 -7.2
# 124 -7.2
# 125 -7.2
# 126 -7.2
# 127 -7.2
# 128 -7.2
# 129 -7.2
# 130 -7.2
# 131 -7.2
# 132 -7.2
# 133 -7.2
# 134 -7.2
# 135 -7.2
# 136 -7.2
# 137 -7.2
# 138 -7.2
# 139 -7.2
# 140 -7.2
# 141 -7.2
# 142 -7.2
# 143 -7.2
# 144 -7.2
# 145 -7.2
# 146 -7.2
# 147 -7.2
# 148 -7.2
# 149 -7.2
# 150 -7.2
# 151 -7.2
# 152 -7.1996
# 153 -7.2
# 154 -7.1994
# 155 -7.2
# 156 -7.2
# 157 -7.2
# 158 -7.2
# 159 -7.2
# 160 -7.2
# 161 -7.2
# 162 -7.19916
# 163 -7.2
# 164 -7.2
# 165 -7.2
# 166 -7.2
# 167 -7.2
# 168 -7.2
# 169 -7.2
# 170 -7.1996
# 171 -7.1994
# 172 -7.2
# 173 -7.2
# 174 -7.2
# 175 -7.2
# 176 -7.2
# 177 -7.2
# 178 -7.2
# 179 -7.2
# 180 -7.2
# 181 -7.2
# 182 -7.2
# 183 -7.2
# 184 -7.2
# 185 -7.2
# 186 -7.2
# 187 -7.2
# 188 -7.2
# 189 -7.2
# 190 -7.2
# 191 -7.2
# 192 -7.2
# 193 -7.2
# 194 -7.1994
# 195 -7.2
# 196 -7.2
# 197 -7.2
# 198 -7.2
# 199 -7.2

# %% [markdown]
# ## f)

# %%
v =1
I = np.eye(2)
H_4 = -(np.kron(pauli_z,I) + np.kron(I, pauli_z)) - np.sqrt(6)/2 * v *(np.kron(pauli_x, I) + 
                                                                       np.kron(I, pauli_x) + 
                                                                       np.kron(pauli_x, pauli_z) - 
                                                                       np.kron(pauli_z, pauli_x))
def H4(v):
    reg = -(np.kron(pauli_z,I) + np.kron(I, pauli_z))
    ireg = - np.sqrt(6)/2 * v *(np.kron(pauli_x,I)+np.kron(I,pauli_x) +np.kron(pauli_x,pauli_z)-np.kron(pauli_z,pauli_x))
    ret = reg + ireg
    return ret
                                                                       
                                                                       
H_4_o = - pauli_z - 3*v*pauli_x


eigval_even, eigvec_even = np.linalg.eig(H_4)
eigval_odd, eigvec_odd = np.linalg.eig(H_4_o)

print(eigval_even)
print(eigval_odd)

H_op = Operator(H_4)


v_list = np.linspace(-2,2,100)
eigval_list = []
for i in range(len(v_list)):
    eig_temp, trash = np.linalg.eig(H4(v_list[i]))
    eigval_list.append(min(eig_temp))
    #print(v_list[i])
    #print(eig_temp)
    #print()
    
plt.plot(v_list, eigval_list)
plt.grid()
# Out:
# [-4.00000000e+00 -2.12178365e-16  4.00000000e+00 -0.00000000e+00]
# [-3.16227766  3.16227766]

# %% [markdown]
# Disse verdiene stemmer på en såkalt prikk med analytiske verdier. Det er jo ganske lovende. Det er mulig her å lage noen fancy plot der vi varierer på v, eller tilnærmer Hartree-Fock?
#
# Det er ganske snodig dette med VQE, men prøver bare:

# %%
def H4lip_func(v):
    h1_lip = [-1, [0,1], ['z']]
    h2_lip = [-np.sqrt(6)/2*v, [0], ['x']]
    h3_lip = [-np.sqrt(6)/2*v, [1], ['x']]
    h4_lip = [-np.sqrt(6)/2*v, [0,1], ['xz']]
    h5_lip = [np.sqrt(6)/2*v, [0,1], ['zx']]
    H4 = [h1_lip, h2_lip, h3_lip, h4_lip, h5_lip]
    return H4

# %%
from qiskit.circuit import QuantumCircuit,\
                           Parameter

def ansatz(theta,n_qubits):
    qreg = QuantumRegister(n_qubits)
    circuit = QuantumCircuit(qreg)
    param_list =[]
    for j in range(len(theta)):
        par = Parameter('theta %s' %j)
        param_list.append(par)
    circuit.ry(param_list[0],qreg[0])
    circuit.cry(param_list[1],qreg[0],qreg[1])
    dictus ={}
    for j in range(len(theta)):
        dictus[param_list[j]] = theta[j]
    circuit = circuit.bind_parameters(dictus)
    circuit = transpile(circuit, backend = simulator)
    return(circuit)

def basis_change(h_i , n_qubits):
    qreg = QuantumRegister(n_qubits)
    bas_circ = QuantumCircuit(qreg)
    bas_circ = bas_circ.compose(ansatz(theta,n_qubits))

    for qubit,operator in zip(h_i[1],h_i[2]):
        if operator == 'x':
            if qubit == 1:
                bas_circ.h(qreg[qubit])
            if qubit == 0:
                bas_circ.h(qreg[qubit])
        if operator == 'xz':
            bas_circ.h(qreg[qubit])
        if operator == 'zx':
            bas_circ.h(qreg[qubit+1])
    return(bas_circ)

def get_energy(theta,v, n_qubits=2):
    H_4_lip = H4lip_func(v)
    qreg = QuantumRegister(n_qubits)
    circuit = QuantumCircuit(qreg)
    circuit_list = []
    for idx,h_i in enumerate(H_4_lip):
        basis_change_circuit = basis_change(h_i,n_qubits)
        new_circuit = circuit.compose(basis_change_circuit)
        creg = ClassicalRegister(len(h_i[1]))
        new_circuit.add_register(creg)
        new_circuit.measure(qreg[h_i[1]],creg)
        circuit_list.append(new_circuit)
    shots = 1000
    job = simulator.run(circuit_list,shots=shots)
    E = np.zeros(len(circuit_list))
    for i in range(len(circuit_list)):
        result = job.result()
        counts = result.get_counts(i)
        for key,value in counts.items():
            e = 1
            for bit in key:
                if bit == '0':
                    e *= 1
                if bit == '1':
                    e *= -1
            E[i] += e*value
        E[i] *= H_4_lip[i][0]
    E /= shots

    #print(E)
    #print(np.mean(E))
    #print(np.std(E))
    return(np.sum(E))

get_energy([0,1], 10)
# Out:
# -6.711805998112636

# %% [markdown]
# Har her en beste på -33.91

# %%
theta = np.random.randn(2)
for epoch in range(epochs):
    print(epoch,get_energy(theta, v=1))
    grad = np.zeros_like(theta)
    for idx in range(theta.shape[0]):
        theta_temp = theta.copy()
        theta_temp[idx] += np.pi/20
        E_plus = get_energy(theta_temp, v =1)
        theta_temp[idx] -= np.pi/10
        E_minus = get_energy(theta_temp, v= 1)
        grad[idx] = (E_plus - E_minus)/2
    theta -= 0.1*grad
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, bar_style='info')))
# 0 1.3714009892709422
# 1 1.263062725186929
# 2 1.401178537953402
# 3 1.440122925124017
# 4 1.346234150782787
# 5 1.460481599496703
# 6 1.3199412943838227
# 7 1.5055622097224637
# 8 1.3846178225518488
# 9 1.4010219046095833
# 10 1.281693845669907
# 11 1.3718300687250524
# 12 1.3891785379534023
# 13 1.4826178225518487
# 14 1.4645724148668
# 15 1.2618504790137255
# 16 1.3526382328405218
# 17 1.3704361918116545
# 18 1.331289763612172
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 10
#       8 theta_temp = theta.copy()
#       9 theta_temp[idx] += np.pi/20
# ---> 10 E_plus = get_energy(theta_temp, v =1)
#      11 theta_temp[idx] -= np.pi/10
#      12 E_minus = get_energy(theta_temp, v= 1)
#
# Cell In[30], line 53, in get_energy(theta, v, n_qubits)
#      51 E = np.zeros(len(circuit_list))
#      52 for i in range(len(circuit_list)):
# ---> 53     result = job.result()
#      54     counts = result.get_counts(i)
#      55     for key,value in counts.items():
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit_aer\jobs\utils.py:41, in requires_submit.<locals>._wrapper(self, *args, **kwargs)
#      39 if self._future is None:
#      40     raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 41 return func(self, *args, **kwargs)
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit_aer\jobs\aerjob.py:78, in AerJob.result(self, timeout)
#      60 @requires_submit
#      61 def result(self, timeout=None):
#      62     # pylint: disable=arguments-differ
#      63     """Get job result. The behavior is the same as the underlying
#      64     concurrent Future objects,
#      65
#    (...)
#      76         concurrent.futures.CancelledError: if job cancelled before completed.
#      77     """
# ---> 78     return self._future.result(timeout=timeout)
#
# File ~\anaconda3\envs\heia\lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File ~\anaconda3\envs\heia\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# Egenverdier skal være $\big[0, \pm 30.01,\pm 34.69 \big]$ for v = 10, der 30 er for 2x2 matrisen.
#
# Det er forskjell i hvilke forventningsverdier jeg får her og i det analytiske. Tror vi at det er fordi rotasjonsgatene påvirker det endelige resultatet, eller er det fordi jeg har implementert gates feil? Tar veldig gjerne input.

# %%
def compute_gradient(theta,v, epsilon=1e-2):
    gradient = np.zeros_like(theta)
    for i in range(len(theta)):
        theta_plus = np.copy(theta)
        theta_minus = np.copy(theta)
        theta_plus[i] += epsilon  #np.pi/10   
        theta_minus[i] -= epsilon #np.pi/10  
        energy_plus = get_energy(theta_plus,v)
        energy_minus = get_energy(theta_minus,v)
        gradient[i] = ((energy_plus - energy_minus) / (2 * epsilon))
    return gradient

def gradient_descent(theta, learning_rate, num_iterations, v):
    min_theta = theta
    min_eval  = get_energy(theta,v)
    for iteration in range(num_iterations):
        energy = get_energy(theta,v)
        gradient = compute_gradient(theta,v)
        theta -= (learning_rate * gradient)
        """
        if iteration%10:
            print("Iteration:", iteration, "Energy:", energy)
        """
        print(energy)
        if energy < min_eval:
            min_theta = theta 
            min_eval  = energy
    return min_theta, min_eval

theta = np.random.randn(2)
learning_rate = 0.4
num_iterations = 100
v = 1
arg_best, arg_val  = gradient_descent(theta, learning_rate, num_iterations,v)
print("The lowest energy is:",arg_val,"with theta values of", arg_best)
# Out:
# -1.933189774026669
# -3.483417275843892
# 1.1094259866673182
# 2.7189606737435645
# -1.919214771423045
# -1.2367469332494503
# -1.083282651254628
# -0.7145561282938504
# -2.9996647245578076
# -1.4771535405570264
# -2.434293319790944
# -0.7692055972076394
# -1.1454188743097735
# 2.156297906898647
# -1.422211215244273
# -3.203514740179554
# 0.051841304798319776
# 2.5811560658068675
# -0.8784244923464074
# -2.8364499531347627
# -0.3157637873593513
# 0.9138525408715867
# -1.475584681868998
# -2.5967428095337275
# -2.0885632406513945
# -0.4558091950443999
# 2.1275397375759293
# -0.3257841976480242
# -0.9842316255329459
# -2.475993814426415
# -0.22245613870834757
# 1.4137413152128169
# -0.6378137821521026
# 3.3826999270985203
# -0.7447744558956675
# -0.08933012079753817
# -0.7230056180366335
# 0.8288198635807161
# 2.9693831042321106
# 2.953687196704342
# 1.901333109439359
# -0.04018369259805607
# 1.5154984536066038
# 0.15442701759624872
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 34
#      32 num_iterations = 100
#      33 v = 1
# ---> 34 arg_best, arg_val  = gradient_descent(theta, learning_rate, num_iterations,v)
#      35 print("The lowest energy is:",arg_val,"with theta values of", arg_best)
#
# Cell In[13], line 18, in gradient_descent(theta, learning_rate, num_iterations, v)
#      16 for iteration in range(num_iterations):
#      17     energy = get_energy(theta,v)
# ---> 18     gradient = compute_gradient(theta,v)
#      19     theta -= (learning_rate * gradient)
#      20     """
#      21     if iteration%10:
#      22         print("Iteration:", iteration, "Energy:", energy)
#      23     """
#
# Cell In[13], line 9, in compute_gradient(theta, v, epsilon)
#       7     theta_minus[i] -= epsilon #np.pi/10
#       8     energy_plus = get_energy(theta_plus,v)
# ----> 9     energy_minus = get_energy(theta_minus,v)
#      10     gradient[i] = ((energy_plus - energy_minus) / (2 * epsilon))
#      11 return gradient
#
# Cell In[5], line 43, in get_energy(theta, v, n_qubits)
#      41 circuit_list = []
#      42 for idx,h_i in enumerate(H_4_lip):
# ---> 43     basis_change_circuit = basis_change(h_i,n_qubits)
#      44     new_circuit = circuit.compose(basis_change_circuit)
#      45     creg = ClassicalRegister(len(h_i[1]))
#
# Cell In[5], line 23, in basis_change(h_i, n_qubits)
#      21 qreg = QuantumRegister(n_qubits)
#      22 bas_circ = QuantumCircuit(qreg)
# ---> 23 bas_circ = bas_circ.compose(ansatz(theta,n_qubits))
#      25 for qubit,operator in zip(h_i[1],h_i[2]):
#      26     if operator == 'x':
#
# Cell In[5], line 16, in ansatz(theta, n_qubits)
#      14 for j in range(len(theta)):
#      15     dictus[param_list[j]] = theta[j]
# ---> 16 circuit = circuit.bind_parameters(dictus)
#      17 circuit = transpile(circuit, backend = simulator)
#      18 return(circuit)
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit\circuit\quantumcircuit.py:2679, in QuantumCircuit.bind_parameters(self, values)
#    2675     if any(isinstance(value, ParameterExpression) for value in values.values()):
#    2676         raise TypeError(
#    2677             "Found ParameterExpression in values; use assign_parameters() instead."
#    2678         )
# -> 2679     return self.assign_parameters(values)
#    2680 else:
#    2681     if any(isinstance(value, ParameterExpression) for value in values):
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit\circuit\quantumcircuit.py:2639, in QuantumCircuit.assign_parameters(self, parameters, inplace)
#    2637     # replace the parameters with a new Parameter ("substitute") or numeric value ("bind")
#    2638     for parameter, value in unrolled_param_dict.items():
# -> 2639         bound_circuit._assign_parameter(parameter, value)
#    2640 else:
#    2641     if len(parameters) != self.num_parameters:
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit\circuit\quantumcircuit.py:2721, in QuantumCircuit._assign_parameter(self, parameter, value)
#    2719 # parameter might be in global phase only
#    2720 if parameter in self._parameter_table:
# -> 2721     for instr, param_index in self._parameter_table[parameter]:
#    2722         assignee = instr.params[param_index]
#    2723         # Normal ParameterExpression.
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit\circuit\parametertable.py:108, in ParameterTable.__getitem__(self, key)
#     107 def __getitem__(self, key):
# --> 108     return self._table[key]
#
# File ~\anaconda3\envs\heia\lib\site-packages\qiskit\circuit\parameter.py:127, in Parameter.__hash__(self)
#     124     else:
#     125         return False
# --> 127 def __hash__(self):
#     128     return self._hash
#     130 def __getstate__(self):
#
# KeyboardInterrupt:

# %%
epochs = 50
v = np.linspace(0,1,100)
min_eigval_list = []
#eps = 3
theta = np.random.randn(2)
learning_rate = 0.08

for i in range(len(v)):
    #a = lip_ham(v[i])
    arg_best, arg_val  = gradient_descent(theta, learning_rate, epochs, v[i])
    min_eigval_list.append(arg_val)
    print(v[i])
    print(arg_val)
    print()

plt.plot(v, min_eigval_list)
# Out:
# 0.0
# -1.0
#
# 0.010101010101010102
# -1.0032659863237108
#
# 0.020202020202020204
# -1.0040082559427361
#
# 0.030303030303030304
# -1.008016511885472
#
# 0.04040404040404041
# -1.0065319726474218
#
# 0.05050505050505051
# -1.0217526278088067
#
# 0.06060606060606061
# -1.0157361159233345
#
# 0.07070707070707072
# -1.0148000357106035
#
# 0.08080808080808081
# -1.0404331053951816
#
# 0.09090909090909091
# -1.043105378053969
#
# 0.10101010101010102
# -1.0538558526005821
#
# 0.11111111111111112
# -1.0623218797364118
#
# 0.12121212121212122
# -1.0320042044940905
#
# 0.13131313131313133
# -1.0418145218717532
#
# 0.14141414141414144
# -1.0777982650620226
#
# 0.15151515151515152
# -1.0911342738535454
#
# 0.16161616161616163
# -1.0502439839394757
#
# 0.17171717171717174
# -1.1968542349974458
#
# 0.18181818181818182
# -1.1938688231888919
#
# 0.19191919191919193
# -1.194986202543353
#
# 0.20202020202020204
# -1.1943101335116615
#
# 0.21212121212121213
# -1.1239260791289873
#
# 0.22222222222222224
# -1.2363761810535503
#
# 0.23232323232323235
# -1.124008536526052
#
# 0.24242424242424243
# -0.9787793448386153
#
# 0.25252525252525254
# -0.6470303348496936
#
# 0.26262626262626265
# -0.7925316155413836
#
# 0.27272727272727276
# -0.8203667007472547
#
# 0.2828282828282829
# -1.2916135521610006
#
# 0.29292929292929293
# -1.3555398098430067
#
# 0.30303030303030304
# -0.9614019798106893
#
# 0.31313131313131315
# -1.1552004744408795
#
# 0.32323232323232326
# -1.0534227982205489
#
# 0.33333333333333337
# -1.203720063174197
#
# 0.3434343434343435
# -1.0100948668187428
#
# 0.3535353535353536
# -1.0147216807773334
#
# 0.36363636363636365
# -1.1790684558798237
#
# 0.37373737373737376
# -1.6264802731028472
#
# 0.38383838383838387
# -1.7039239917635518
#
# 0.393939393939394
# -1.6165463461523102
#
# 0.4040404040404041
# -0.6136287376526165
#
# 0.4141414141414142
# -0.650712761637669
#
# 0.42424242424242425
# -1.7319365542306748
#
# 0.43434343434343436
# -1.6378331508858803
#
# 0.4444444444444445
# -0.26095534266056647
#
# 0.4545454545454546
# -0.8005769977188582
#
# 0.4646464646464647
# -1.370739085427901
#
# 0.4747474747474748
# -1.4627434174598624
#
# 0.48484848484848486
# -1.5631354216943825
#
# 0.494949494949495
# -1.3720214560992132
#
# 0.5050505050505051
# -1.0630929176171424
#
# 0.5151515151515152
# -1.6293008466399947
#
# 0.5252525252525253
# -1.2370397386332668
#
# 0.5353535353535354
# -1.2134190528627928
#
# 0.5454545454545455
# -1.0668042657122687
#
# 0.5555555555555556
# -1.5415271963607355
#
# 0.5656565656565657
# -1.9318663532098441
#
# 0.5757575757575758
# -1.7059607863998258
#
# 0.5858585858585859
# -2.018444269201371
#
# 0.595959595959596
# -0.40271666004086976
#
# 0.6060606060606061
# -1.4976920091245676
#
# 0.6161616161616162
# -1.4128506426851348
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-ecc5e845d920> in <module>
#       8 for i in range(len(v)):
#       9     #a = lip_ham(v[i])
# ---> 10     arg_best, arg_val  = gradient_descent(theta, learning_rate, epochs, v[i])
#      11     min_eigval_list.append(arg_val)
#      12     print(v[i])
#
# <ipython-input-20-bcd78c783114> in gradient_descent(theta, learning_rate, num_iterations, v)
#      16     for iteration in range(num_iterations):
#      17         energy = get_energy(theta,v)
# ---> 18         gradient = compute_gradient(theta,v)
#      19         theta -= (learning_rate * gradient)
#      20         """
#
# <ipython-input-20-bcd78c783114> in compute_gradient(theta, v, epsilon)
#       6         theta_plus[i] += epsilon  #np.pi/10
#       7         theta_minus[i] -= epsilon #np.pi/10
# ----> 8         energy_plus = get_energy(theta_plus,v)
#       9         energy_minus = get_energy(theta_minus,v)
#      10         gradient[i] = ((energy_plus - energy_minus) / (2 * epsilon))
#
# <ipython-input-14-992f6b1b8190> in get_energy(theta, v, n_qubits)
#      41     circuit_list = []
#      42     for idx,h_i in enumerate(H_4_lip):
# ---> 43         basis_change_circuit = basis_change(h_i,n_qubits)
#      44         new_circuit = circuit.compose(basis_change_circuit)
#      45         creg = ClassicalRegister(len(h_i[1]))
#
# <ipython-input-14-992f6b1b8190> in basis_change(h_i, n_qubits)
#      21     qreg = QuantumRegister(n_qubits)
#      22     bas_circ = QuantumCircuit(qreg)
# ---> 23     bas_circ = bas_circ.compose(ansatz(theta,n_qubits))
#      24
#      25     for qubit,operator in zip(h_i[1],h_i[2]):
#
# <ipython-input-14-992f6b1b8190> in ansatz(theta, n_qubits)
#      15         dictus[param_list[j]] = theta[j]
#      16     circuit = circuit.bind_parameters(dictus)
# ---> 17     circuit = transpile(circuit, backend = simulator)
#      18     return(circuit)
#      19
#
# ~\Anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     333
#     334     # Transpile circuits in parallel
# --> 335     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     336
#     337     end_time = time()
#
# ~\Anaconda3\lib\site-packages\qiskit\tools\parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     130         return []
#     131     if len(values) == 1:
# --> 132         return [task(values[0], *task_args, **task_kwargs)]
#     133
#     134     Publisher().publish("terra.parallel.start", len(values))
#
# ~\Anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in _transpile_circuit(circuit_config_tuple)
#     428
#     429     result = pass_manager.run(
# --> 430         circuit, callback=transpile_config["callback"], output_name=transpile_config["output_name"]
#     431     )
#     432
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\passmanager.py in run(self, circuits, output_name, callback)
#     216             return circuits
#     217         if isinstance(circuits, QuantumCircuit):
# --> 218             return self._run_single_circuit(circuits, output_name, callback)
#     219         if len(circuits) == 1:
#     220             return self._run_single_circuit(circuits[0], output_name, callback)
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     271         """
#     272         running_passmanager = self._create_running_passmanager()
# --> 273         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     274         self.property_set = running_passmanager.property_set
#     275         return result
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\runningpassmanager.py in run(***failed resolving arguments***)
#     121         for passset in self.working_list:
#     122             for pass_ in passset:
# --> 123                 dag = self._do_pass(pass_, dag, passset.options)
#     124
#     125         circuit = dag_to_circuit(dag)
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     152         # Run the pass itself, if not already run
#     153         if pass_ not in self.valid_passes:
# --> 154             dag = self._run_this_pass(pass_, dag)
#     155
#     156             # update the valid_passes property
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     164             # Measure time if we have a callback or logging set
#     165             start_time = time()
# --> 166             new_dag = pass_.run(dag)
#     167             end_time = time()
#     168             run_time = end_time - start_time
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py in run(self, dag)
#     166                     continue
#     167
# --> 168             new_basis, new_circ = self._resynthesize_run(run)
#     169
#     170             if new_circ is not None and self._substitution_checks(dag, run, new_circ, new_basis):
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py in _resynthesize_run(self, run)
#      76             operator = gate.op.to_matrix().dot(operator)
#      77
# ---> 78         new_circs = {k: v._decompose(operator) for k, v in self._decomposers.items()}
#      79
#      80         new_basis, new_circ = None, None
#
# ~\Anaconda3\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py in <dictcomp>(.0)
#      76             operator = gate.op.to_matrix().dot(operator)
#      77
# ---> 78         new_circs = {k: v._decompose(operator) for k, v in self._decomposers.items()}
#      79
#      80         new_basis, new_circ = None, None
#
# ~\Anaconda3\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py in _decompose(self, unitary, simplify, atol)
#     165
#     166     def _decompose(self, unitary, simplify=True, atol=DEFAULT_ATOL):
# --> 167         theta, phi, lam, phase = self._params(unitary)
#     168         circuit = self._circuit(theta, phi, lam, phase, simplify=simplify, atol=atol)
#     169         return circuit
#
# ~\Anaconda3\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py in _params_zyz(mat)
#     224         # We rescale the input matrix to be special unitary (det(U) = 1)
#     225         # This ensures that the quaternion representation is real
# --> 226         coeff = la.det(mat) ** (-0.5)
#     227         phase = -cmath.phase(coeff)
#     228         su_mat = coeff * mat  # U in SU(2)
#
# ~\Anaconda3\lib\site-packages\scipy\linalg\basic.py in det(a, overwrite_a, check_finite)
#    1035     overwrite_a = overwrite_a or _datacopied(a1, a)
#    1036     fdet, = get_flinalg_funcs(('det',), (a1,))
# -> 1037     a_det, info = fdet(a1, overwrite_a=overwrite_a)
#    1038     if info < 0:
#    1039         raise ValueError('illegal value in %d-th argument of internal '
#
# KeyboardInterrupt:
